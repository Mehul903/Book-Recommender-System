# %%
# %load_ext autotime

# %%
import gzip
import csv
# Out:
# time: 15.5 ms

# %% [markdown]
# ### Somewhat optimized version of reading and writing book-reviews file:

# %% [markdown]
# #### Basic info about the file:
# 1. Total #reviews in file: 12,886,488
# 2. Total #rows in file: 141,751,368

# %%
col_names = ['productID', 'title', 'price', 'userID', 'profileName', 
             'helpfulness', 'score', 'time', 'summary', 'text']
# Out:
# time: 15.5 ms

# %%
def process_data(n):
    
    """
    The function reads the txt.gz file, which contains all the reviews, line-by-line, and when it 
    gathers all the data for a sinngle review, it writes (or adds) a single row for that review in a 
    csv file, and does this for all ~13M reviews.
    
    Estimated completion time for ~13M reviews: 20 min
    Estimated size of file for ~13M reviews: 10 GB 
    
    Args:
        n (int): #rows to read, provide n as a multiple of 11.
                    If n = 1100, then fetches data for 1100/11 = 100 users.
                    
    Returns:
        None
    
    """
    
    cnt = 0
    temp = []
    
    with gzip.open('E:\\MRP\\0102\\Books.txt.gz') as rf:
        with open('E:\\MRP\\0102\\Books.csv', 'w', newline = '') as cw:
            csv_writer = csv.writer(cw, delimiter = ',')
            
            while cnt < n:
                l1 = rf.readline().decode('utf-8')
                
                if len(l1) > 1:                
                    value = l1.split(':')[1].strip('\n')                  
                    temp.append(value)
                else:
                    csv_writer.writerow(temp)
                    temp = []

                cnt+=1          
            
    return None

all_records = process_data(141751368)
# Out:
# time: 17min 31s

# %% [markdown]
# ### Need to strip white-spaces from some of the columns: 1) title

# %%
sample = pd.read_csv('E://MRP//0102//Books.csv', nrows = 500, names=col_names)
# Out:
# time: 111 ms

# %%
sample.head()
# Out:
#     productID                            title     price           userID  \
# 0  1882931173   Its Only Art If Its Well Hung!   unknown    AVCGYZL8FQQTD
# 1   826414346                        Dr. Seuss   unknown   A30TK6U7DNS82R
# 2   826414346                        Dr. Seuss   unknown   A3UH4UZ4RSVO82
# 3   826414346                        Dr. Seuss   unknown   A2MVUWT453QH61
# 4   826414346                        Dr. Seuss   unknown   A22X4XUPKF66MR
#
#                            profileName helpfulness  score        time  \
# 0                Jim of Oz "jim-of-oz"         7/7    4.0   940636800
# 1                        Kevin Killian       10/10    5.0  1095724800
# 2                         John Granger       10/11    5.0  1078790400
# 3   Roy E. Perry "amateur philosopher"         7/7    4.0  1090713600
# 4      D. H. Richards "ninthwavestore"         3/3    4.0  1107993600
#
#                                             summary  \
# 0            Nice collection of Julie Strain images
# 1                                 Really Enjoyed It
# 2   Essential for every personal and Public Library
# 3   Phlip Nel gives silly Seuss a serious treatment
# 4                            Good academic overview
#
#                                                 text
# 0   This is only for Julie Strain fans. It's a co...
# 1   I don't care much for Dr. Seuss but after rea...
# 2   If people become the books they read and if "...
# 3   Theodore Seuss Geisel (1904-1991), aka &quot;...
# 4                             Philip Nel - Dr. Seuss
# time: 36 ms

# %%
pd.pivot_table(data = sample, index = 'userID', columns = 'title', values = 'score')
# Out:
# title             Dr. Seuss   Its Only Art If Its Well Hung!   Nation Dance  \
# userID
#  A14OJS0VWMOSWO         5.0                              NaN            NaN
#  A16FTKP8BXKGHG         NaN                              NaN            NaN
#  A1E9M6APK30ZAU         NaN                              NaN            NaN
#  A1EONVY639PQDY         NaN                              NaN            NaN
#  A1KAKU5SCNNEZM         NaN                              NaN            NaN
#  A1N38F1DJ9H2KM         NaN                              NaN            NaN
#  A1P2KGE2Z8RTA          NaN                              NaN            NaN
#  A1VK81CRRC7MLM         NaN                              NaN            NaN
#  A1XNI3654I4ME2         NaN                              NaN            NaN
#  A1YLDZ3VHR6QPZ         NaN                              NaN            NaN
#  A22X4XUPKF66MR         4.0                              NaN            NaN
#  A25MD5I2GUIW6W         5.0                              NaN            NaN
#  A29I6N5F8P386Y         NaN                              NaN            NaN
#  A2ABV8FXF88O9P         NaN                              NaN            NaN
#  A2BAF61XBWSLH          NaN                              NaN            NaN
#  A2F6NONFUDB6UK         4.0                              NaN            NaN
#  A2GKUH6OBW7POH         NaN                              NaN            NaN
#  A2MVUWT453QH61         4.0                              NaN            NaN
#  A2RSSXTDZDUSH4         5.0                              NaN            NaN
#  A2XXVRH6VJ8S7Q         NaN                              NaN            NaN
#  A2YWUISTJ728T5         NaN                              NaN            NaN
#  A30TK6U7DNS82R         5.0                              NaN            NaN
#  A36TPZSH8LBT1          NaN                              NaN            NaN
#  A373VVEU6Z9M0N         NaN                              NaN            NaN
#  A38P0UQN2C364Y         NaN                              NaN            NaN
#  A3OQWLU31BU1Y          NaN                              NaN            NaN
#  A3OS2QHEH495TD         NaN                              NaN            NaN
#  A3OZDTEEAF8GS9         NaN                              NaN            NaN
#  A3Q12RK71N74LB         NaN                              NaN            NaN
#  A3S5YQQWBO0LGI         NaN                              NaN            NaN
#  A3T591DTKPYCVW         NaN                              NaN            NaN
#  A3U1XS6XK6YUU4         NaN                              NaN            NaN
#  A3UH4UZ4RSVO82         5.0                              NaN            NaN
#  A3V4NY81KXZAUL         NaN                              NaN            NaN
#  A3VA4XFS5WNJO3         4.0                              NaN            NaN
#  A3VSJF0K4H28XK         NaN                              NaN            NaN
#  A6OQ83FD8E2OC          NaN                              NaN            NaN
#  A9L6GHJC42RRC          NaN                              NaN            NaN
#  ACO23CG8K8T77          NaN                              NaN            NaN
#  AE5JROER4ERSO          NaN                              NaN            NaN
#  AGKGOH65VTRR4          NaN                              NaN            NaN
#  AJV5HX8BBZKEP                     NaN                             4.0
#  AN9WUW5BG7M39                     NaN                             NaN
#  ANX3DDV12ZRRU                     4.0                             NaN
#  ARI272XF8TOL4                     5.0                             NaN
#  ASEIU33YVKKWW                     NaN                             5.0
#  AUR0VA5H0C66C                     NaN                             1.0
#  AVCGYZL8FQQTD                     NaN                             NaN
#  AVRN9E6X9I6KF                     NaN                             5.0
#  AZ0IOBU20TBOP                     NaN                             NaN
#
# title             Wonderful Worship in Smaller Churches
# userID
#  A14OJS0VWMOSWO                                     NaN
#  A16FTKP8BXKGHG                                     NaN
#  A1E9M6APK30ZAU                                     NaN
#  A1EONVY639PQDY                                     NaN
#  A1KAKU5SCNNEZM                                     NaN
#  A1N38F1DJ9H2KM                                     NaN
#  A1P2KGE2Z8RTA                                      NaN
#  A1VK81CRRC7MLM                                     NaN
#  A1XNI3654I4ME2                                     NaN
#  A1YLDZ3VHR6QPZ                                     NaN
#  A22X4XUPKF66MR                                     NaN
#  A25MD5I2GUIW6W                                     NaN
#  A29I6N5F8P386Y                                     NaN
#  A2ABV8FXF88O9P                                     NaN
#  A2BAF61XBWSLH                                      NaN
#  A2F6NONFUDB6UK                                     NaN
#  A2GKUH6OBW7POH                                     NaN
#  A2MVUWT453QH61                                     NaN
#  A2RSSXTDZDUSH4                                     NaN
#  A2XXVRH6VJ8S7Q                                     NaN
#  A2YWUISTJ728T5                                     NaN
#  A30TK6U7DNS82R                                     NaN
#  A36TPZSH8LBT1                                      NaN
#  A373VVEU6Z9M0N                                     5.0
#  A38P0UQN2C364Y                                     NaN
#  A3OQWLU31BU1Y                                      5.0
#  A3OS2QHEH495TD                                     NaN
#  A3OZDTEEAF8GS9                                     NaN
#  A3Q12RK71N74LB                                     NaN
#  A3S5YQQWBO0LGI                                     NaN
#  A3T591DTKPYCVW                                     NaN
#  A3U1XS6XK6YUU4                                     NaN
#  A3UH4UZ4RSVO82                                     NaN
#  A3V4NY81KXZAUL                                     NaN
#  A3VA4XFS5WNJO3                                     NaN
#  A3VSJF0K4H28XK                                     NaN
#  A6OQ83FD8E2OC                                      NaN
#  A9L6GHJC42RRC                                      NaN
#  ACO23CG8K8T77                                      NaN
#  AE5JROER4ERSO                                      NaN
#  AGKGOH65VTRR4                                      5.0
#  AJV5HX8BBZKEP                                      NaN
#  AN9WUW5BG7M39                                      NaN
#  ANX3DDV12ZRRU                                      NaN
#  ARI272XF8TOL4                                      NaN
#  ASEIU33YVKKWW                                      NaN
#  AUR0VA5H0C66C                                      NaN
#  AVCGYZL8FQQTD                                      NaN
#  AVRN9E6X9I6KF                                      NaN
#  AZ0IOBU20TBOP                                      5.0
# time: 281 ms
